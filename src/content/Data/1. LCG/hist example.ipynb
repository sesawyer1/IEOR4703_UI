# %% [markdown]
# # Monte Carlo Simulation for FE
# ## IEOR 4703

# %% [markdown]
# ### Histogram Example

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 1000
ru = np.random.rand(N)

# %%
plt.hist(ru, bins=10)
plt.show()

# %%
plt.hist(ru, bins=50)
plt.show()
