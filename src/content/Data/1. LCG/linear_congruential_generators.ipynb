# %% [markdown]
# # Monte Carlo Simulation for FE
# ## IEOR 4703

# %% [markdown]
# ### Example of a linear congruential generator

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
m = 2**31 - 1
a = 7**5
c = 0

#seed
x = 98654

n = 100000

# %%
rand_U = np.zeros(n)

for i in range(n):
    x = (a*x + c) % m
    rand_U[i] = 1.*x / (m + 1)

# %%
plt.hist(rand_U, bins=10)
plt.show()
