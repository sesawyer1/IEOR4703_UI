# %% [markdown]
# # Monte Carlo Simulation for FE
# ## IEOR 4703

# %% [markdown]
# ### Changing and testing random seeds

# %%
import numpy as np

# %% [markdown]
# Testing seeds with Numpy function **np.random.seed**

# %%
#np.random.seed(12345)
u = np.random.rand(10)
print(u)
# Out:
# [0.43521873 0.63543782 0.80114668 0.60417891 0.2988146  0.86851132
#  0.183979   0.03106258 0.8630902  0.94767224]

# %%
np.random.seed(46575)
u = np.random.rand(10)
print(u)
# Out:
# [0.90333963 0.40091541 0.5060878  0.3778826  0.54033465 0.8104651
#  0.05262951 0.35645444 0.49623942 0.18223623]

# %%
np.random.seed(12345)
u = np.random.rand(10)
print(u)
# Out:
# [0.92961609 0.31637555 0.18391881 0.20456028 0.56772503 0.5955447
#  0.96451452 0.6531771  0.74890664 0.65356987]

# %%
np.random.seed(46575)
u = np.random.rand(10)
print(u)
# Out:
# [0.90333963 0.40091541 0.5060878  0.3778826  0.54033465 0.8104651
#  0.05262951 0.35645444 0.49623942 0.18223623]
