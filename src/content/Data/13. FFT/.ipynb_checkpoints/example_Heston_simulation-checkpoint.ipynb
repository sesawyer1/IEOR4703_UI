# %% [markdown]
# # IEOR 4703 -- Monte Carlo Simulation for FE

# %% [markdown]
# ## Pricing Heston via simulation

# %%
import numpy as np
from time import time

# %% [markdown]
# ### Option parameters:

# %%
s0 = 100
K = 80
r = 0.05
q = 0.01
T = 1

# %% [markdown]
# ### Heston Parameters:

# %%
kappa = 1.75
theta = 0.0625
sig = 0.025
rho = -0.2
v_0 = 0.10
#
sigma = 0.3

# %%
n_sims = 100000
m = 12
dt = T / m

# %%
np.random.seed(7181426)

# %%
st = time()

payoff1 = 0
payoff2 = 0

for j in range(n_sims):
    
    if (j%10000 == 0):
        print(j)
    
    logS1 = np.log(s0)
    logS2 = np.log(s0)
    logS3 = np.log(s0)
    #
    v = v_0
    #
    z_v = np.random.randn(m)
    z   = np.random.randn(m)
    z_S = rho*z_v + np.sqrt(1-rho**2)*z
    #
    for i in range(m):  
        # Euler discretization
        v_pre = v
        v     = v + kappa*(theta-v)*dt + sig*np.sqrt(v*dt)*z_v[i]
        if (v < 0):
            print(v)
            v = 0.001
        
        logS1 += (r - q - 0.5*v    )*dt + sigma*z_S[i]
        logS2 += (r - q - 0.5*v_pre)*dt + np.sqrt(v_pre*dt)*z_S[i]
        logS3 += (r - q - 0.5*v    )*dt + np.sqrt(v    *dt)*z_S[i]

    
    payoff1 += max(np.exp(logS1) - K, 0)
    payoff2 += max(np.exp(logS2) - K, 0)
    payoff3 += max(np.exp(logS3) - K, 0)

c1 = np.exp(-r*T) * payoff1 / n_sims
c2 = np.exp(-r*T) * payoff2 / n_sims
c3 = np.exp(-r*T) * payoff2 / n_sims

et = time()
print('Elapsed times was %f seconds' % (et-st))
# Out:
# 0
# UsageError: Line magic function `%` not found.

# %%
print('BMS (Euler)       = %f' % c1)
print('Heston_1 (Euler)  = %f' % c2)
print('Heston_2 (Euler0  = %f' % c3)
# Out:
# Euler  = 25.363279
# Euler  = 25.042922
