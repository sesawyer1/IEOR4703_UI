# %% [markdown]
# # IEOR 4703 -- Monte Carlo Simulation for FE

# %% [markdown]
# ### Simulation of a finite state space Markov Chain

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def simulate_markov(num_states, num_steps):
    
    ''' Simulate a Markov chain '''
    # define a random probability transition matrix
    unnormalizedP = np.random.rand(num_states, num_states)
    
    #a bit of a manipulation
    #unnormalizedP[0, 0] = 15
    #unnormalizedP[1, 1] = 20
    sum_rows = np.sum(unnormalizedP, axis=1)
    P = (unnormalizedP.T / sum_rows).T # rows should add up to 1
    
    print('==========================================')
    print('      Transition probability matrix:      ')
    print('------------------------------------------')
    print(np.round(P, 2))
    print(' ')
    
    # cdf for each state
    cumP = np.cumsum(P, axis=1)
    cumP[:, -1] = 1. # avoid numerical errors
    
    x = np.zeros(num_steps+1, dtype=int)
    # random initial state, from 0 to num_states-1
    x[0] = np.int(num_states * np.random.rand())
    print('Iteration 0: initial state %i' % x[0])
    
    state = np.arange(num_states, dtype=int)
    # chain simulation
    u = np.random.rand(num_steps)
    for k in range(num_steps):
        
        # current state
        i = x[k]
        
        # select the corresponding cdf
        p = cumP[i, :]
        
        # select next state
        j = np.min(state[u[k] <= p])
        x[k + 1] = j
        
        print('iter=%i: transitioning from state %i to state %i' % (k+1, i, j))
        
    return x

# %%
num_states = 7
num_steps = 130
chain = simulate_markov(num_states, num_steps)
# Out:
# ==========================================
#       Transition probability matrix:
# ------------------------------------------
# [[0.89 0.01 0.01 0.04 0.   0.02 0.03]
#  [0.03 0.86 0.03 0.03 0.03 0.01 0.02]
#  [0.15 0.22 0.01 0.13 0.18 0.25 0.06]
#  [0.14 0.25 0.07 0.05 0.14 0.13 0.22]
#  [0.18 0.2  0.09 0.17 0.18 0.16 0.02]
#  [0.15 0.21 0.01 0.18 0.1  0.27 0.08]
#  [0.02 0.04 0.17 0.16 0.16 0.3  0.14]]
#
# Iteration 0: initial state 2
# iter=1: transitioning from state 2 to state 0
# iter=2: transitioning from state 0 to state 0
# iter=3: transitioning from state 0 to state 0
# iter=4: transitioning from state 0 to state 0
# iter=5: transitioning from state 0 to state 0
# iter=6: transitioning from state 0 to state 0
# iter=7: transitioning from state 0 to state 0
# iter=8: transitioning from state 0 to state 0
# iter=9: transitioning from state 0 to state 0
# iter=10: transitioning from state 0 to state 0
# iter=11: transitioning from state 0 to state 0
# iter=12: transitioning from state 0 to state 3
# iter=13: transitioning from state 3 to state 1
# iter=14: transitioning from state 1 to state 1
# iter=15: transitioning from state 1 to state 1
# iter=16: transitioning from state 1 to state 1
# iter=17: transitioning from state 1 to state 1
# iter=18: transitioning from state 1 to state 1
# iter=19: transitioning from state 1 to state 1
# iter=20: transitioning from state 1 to state 1
# iter=21: transitioning from state 1 to state 1
# iter=22: transitioning from state 1 to state 1
# iter=23: transitioning from state 1 to state 1
# iter=24: transitioning from state 1 to state 1
# iter=25: transitioning from state 1 to state 5
# iter=26: transitioning from state 5 to state 4
# iter=27: transitioning from state 4 to state 3
# iter=28: transitioning from state 3 to state 6
# iter=29: transitioning from state 6 to state 3
# iter=30: transitioning from state 3 to state 0
# iter=31: transitioning from state 0 to state 0
# iter=32: transitioning from state 0 to state 0
# iter=33: transitioning from state 0 to state 0
# iter=34: transitioning from state 0 to state 0
# iter=35: transitioning from state 0 to state 1
# iter=36: transitioning from state 1 to state 1
# iter=37: transitioning from state 1 to state 1
# iter=38: transitioning from state 1 to state 1
# iter=39: transitioning from state 1 to state 1
# iter=40: transitioning from state 1 to state 5
# iter=41: transitioning from state 5 to state 0
# iter=42: transitioning from state 0 to state 1
# iter=43: transitioning from state 1 to state 1
# iter=44: transitioning from state 1 to state 1
# iter=45: transitioning from state 1 to state 1
# iter=46: transitioning from state 1 to state 1
# iter=47: transitioning from state 1 to state 2
# iter=48: transitioning from state 2 to state 5
# iter=49: transitioning from state 5 to state 5
# iter=50: transitioning from state 5 to state 3
# iter=51: transitioning from state 3 to state 1
# iter=52: transitioning from state 1 to state 1
# iter=53: transitioning from state 1 to state 1
# iter=54: transitioning from state 1 to state 1
# iter=55: transitioning from state 1 to state 1
# iter=56: transitioning from state 1 to state 6
# iter=57: transitioning from state 6 to state 5
# iter=58: transitioning from state 5 to state 5
# iter=59: transitioning from state 5 to state 5
# iter=60: transitioning from state 5 to state 1
# iter=61: transitioning from state 1 to state 3
# iter=62: transitioning from state 3 to state 6
# iter=63: transitioning from state 6 to state 2
# iter=64: transitioning from state 2 to state 4
# iter=65: transitioning from state 4 to state 0
# iter=66: transitioning from state 0 to state 0
# iter=67: transitioning from state 0 to state 0
# iter=68: transitioning from state 0 to state 0
# iter=69: transitioning from state 0 to state 0
# iter=70: transitioning from state 0 to state 0
# iter=71: transitioning from state 0 to state 0
# iter=72: transitioning from state 0 to state 0
# iter=73: transitioning from state 0 to state 0
# iter=74: transitioning from state 0 to state 0
# iter=75: transitioning from state 0 to state 0
# iter=76: transitioning from state 0 to state 0
# iter=77: transitioning from state 0 to state 0
# iter=78: transitioning from state 0 to state 3
# iter=79: transitioning from state 3 to state 1
# iter=80: transitioning from state 1 to state 1
# iter=81: transitioning from state 1 to state 1
# iter=82: transitioning from state 1 to state 1
# iter=83: transitioning from state 1 to state 1
# iter=84: transitioning from state 1 to state 0
# iter=85: transitioning from state 0 to state 0
# iter=86: transitioning from state 0 to state 0
# iter=87: transitioning from state 0 to state 6
# iter=88: transitioning from state 6 to state 5
# iter=89: transitioning from state 5 to state 4
# iter=90: transitioning from state 4 to state 3
# iter=91: transitioning from state 3 to state 0
# iter=92: transitioning from state 0 to state 0
# iter=93: transitioning from state 0 to state 1
# iter=94: transitioning from state 1 to state 1
# iter=95: transitioning from state 1 to state 1
# iter=96: transitioning from state 1 to state 1
# iter=97: transitioning from state 1 to state 1
# iter=98: transitioning from state 1 to state 1
# iter=99: transitioning from state 1 to state 1
# iter=100: transitioning from state 1 to state 6
# iter=101: transitioning from state 6 to state 1
# iter=102: transitioning from state 1 to state 1
# iter=103: transitioning from state 1 to state 1
# iter=104: transitioning from state 1 to state 1
# iter=105: transitioning from state 1 to state 1
# iter=106: transitioning from state 1 to state 0
# iter=107: transitioning from state 0 to state 0
# iter=108: transitioning from state 0 to state 0
# iter=109: transitioning from state 0 to state 0
# iter=110: transitioning from state 0 to state 0
# iter=111: transitioning from state 0 to state 3
# iter=112: transitioning from state 3 to state 6
# iter=113: transitioning from state 6 to state 4
# iter=114: transitioning from state 4 to state 1
# iter=115: transitioning from state 1 to state 1
# iter=116: transitioning from state 1 to state 1
# iter=117: transitioning from state 1 to state 1
# iter=118: transitioning from state 1 to state 1
# iter=119: transitioning from state 1 to state 1
# iter=120: transitioning from state 1 to state 1
# iter=121: transitioning from state 1 to state 1
# iter=122: transitioning from state 1 to state 1
# iter=123: transitioning from state 1 to state 1
# iter=124: transitioning from state 1 to state 1
# iter=125: transitioning from state 1 to state 1
# iter=126: transitioning from state 1 to state 1
# iter=127: transitioning from state 1 to state 1
# iter=128: transitioning from state 1 to state 1
# iter=129: transitioning from state 1 to state 1
# iter=130: transitioning from state 1 to state 1

# %%
plt.figure(figsize=(20, 4))
plt.plot(np.arange(num_steps+1, dtype=int), chain, 'o--')
plt.xlabel('iteration')
plt.ylabel('state')
plt.title('Markov Chain with %i states' % num_states)
plt.show()
